# %% [markdown]
# # CITY LIFE. Clustering analysis

# %% [markdown]
# ## Task

# %% [markdown]
# In this project, you will try to get some valuable insights about customers’
# and taxi drivers’ behavior. Maybe it will help a taxi company optimize its
# business.
# Here are the tasks that you need to do:
# 1. find out and visualize on a map most popular areas where people ordered a taxi as
# well as where they headed to,
# 2. find out and visualize the most popular routes in different time intervals,
# 3. find in the dataset locations of the city infrastructure and visualize how the customers were arriving at one of them using an animated map,
# 4. visualize one day of a taxi driver and how much money he or she earned using an
# animated map,
# 5. visualize one day of the city (working day and weekend day) using an animated
# map.

# %% [markdown]
# ## Imports

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shapely
import folium


from shapely.geometry import Polygon, LineString, Point

# %% [markdown]
# ## Load data

# %%
df_map = gpd.read_file('data/chicago_map.shx')

# %%
df_map.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   geometry  77 non-null     geometry
# dtypes: geometry(1)
# memory usage: 744.0 bytes

# %%
rush = gpd.read_file('data/rush_hours_empty.csv')

# %%
rush.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                1 non-null      object
#  1   longitude           1 non-null      object
#  2   latitude            1 non-null      object
#  3   num_of_rides        1 non-null      object
#  4   Trip End Timestamp  1 non-null      object
#  5   geometry            0 non-null      geometry
# dtypes: geometry(1), object(5)
# memory usage: 176.0+ bytes

# %%
taxi_loc = gpd.read_file('data/taxi_locations.csv')

# %%
taxi_loc.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2506294 entries, 0 to 2506293
# Data columns (total 12 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Trip ID                     object
#  1   Pickup Centroid Latitude    object
#  2   Pickup Centroid Longitude   object
#  3   Pickup Centroid Location    object
#  4   Dropoff Centroid Latitude   object
#  5   Dropoff Centroid Longitude  object
#  6   Dropoff Centroid  Location  object
#  7   Trip Start Timestamp        object
#  8   Trip End Timestamp          object
#  9   Taxi ID                     object
#  10  Fare                        object
#  11  geometry                    geometry
# dtypes: geometry(1), object(11)
# memory usage: 229.5+ MB

# %% [markdown]
# ## Data preparation

# %%
df_map.set_crs(epsg=4326, inplace=True)
# Out:
#                                              geometry
# 0   POLYGON ((-87.60914 41.84469, -87.60915 41.844...
# 1   POLYGON ((-87.59215 41.81693, -87.59231 41.816...
# 2   POLYGON ((-87.62880 41.80189, -87.62879 41.801...
# 3   POLYGON ((-87.60671 41.81681, -87.60670 41.816...
# 4   POLYGON ((-87.59215 41.81693, -87.59215 41.816...
# ..                                                ...
# 72  POLYGON ((-87.69646 41.70714, -87.69644 41.706...
# 73  POLYGON ((-87.64215 41.68508, -87.64249 41.685...
# 74  MULTIPOLYGON (((-87.83658 41.98640, -87.83658 ...
# 75  POLYGON ((-87.65456 41.99817, -87.65456 41.998...
# 76  POLYGON ((-87.80676 42.00084, -87.80676 42.000...
#
# [77 rows x 1 columns]

# %%
m = folium.Map(location=[41.85, -87.65], zoom_start=10, tiles='CartoDB positron')

# %%
for _, r in df_map.iterrows():
    sim_geo = gpd.GeoSeries(r['geometry']).simplify(tolerance=0.001)
    geo_j = sim_geo.to_json()
    geo_j = folium.GeoJson(data=geo_j,
                           style_function=lambda x: {'fillColor': 'orange'})
    geo_j.add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc3f96d0ef0a064982d85a9dcb0f3f81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc3f96d0ef0a064982d85a9dcb0f3f81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc3f96d0ef0a064982d85a9dcb0f3f81 = L.map(
#                 &quot;map_cc3f96d0ef0a064982d85a9dcb0f3f81&quot;,
#                 {
#                     center: [41.85, -87.65],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9172e982146458a7113fd0f38655394 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cc3f96d0ef0a064982d85a9dcb0f3f81);
#
#
#         function geo_json_ce164eb5773c20d59e18e381f6a1a8a1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_ce164eb5773c20d59e18e381f6a1a8a1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ce164eb5773c20d59e18e381f6a1a8a1 = L.geoJson(null, {
#                 onEachFeature: geo_json_ce164eb5773c20d59e18e381f6a1a8a1_onEachFeature,
#
#                 style: geo_json_ce164eb5773c20d59e18e381f6a1a8a1_styler,
#         });
#
#         function geo_json_ce164eb5773c20d59e18e381f6a1a8a1_add (data) {
#             geo_json_ce164eb5773c20d59e18e381f6a1a8a1
#                 .addData(data)
#                 .addTo(map_cc3f96d0ef0a064982d85a9dcb0f3f81);
#         }
#             geo_json_ce164eb5773c20d59e18e381f6a1a8a1_add({&quot;bbox&quot;: [-87.62996524440503, 41.823681491629785, -87.60271020373473, 41.8455448376101], &quot;features&quot;: [{&quot;bbox&quot;: [-87.62996524440503, 41.823681491629785, -87.60271020373473, 41.8455448376101], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.60914087617894, 41.84469250265398], [-87.60709523007235, 41.83951203695919], [-87.60418506322291, 41.839828572849825], [-87.60607167523855, 41.837293058456886], [-87.60271020373473, 41.83136624686849], [-87.61063335779062, 41.83118622461551], [-87.61262427240324, 41.82389080436826], [-87.62896819971361, 41.823681491629785], [-87.62996524440503, 41.8455448376101], [-87.60914087617894, 41.84469250265398]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_7681bcf9d076fe4ec4814aa15770c278_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_7681bcf9d076fe4ec4814aa15770c278_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7681bcf9d076fe4ec4814aa15770c278 = L.geoJson(null, {
#                 onEachFeature: geo_json_7681bcf9d076fe4ec4814aa15770c278_onEachFeature,
#
#                 style: geo_json_7681bcf9d076fe4ec4814aa15770c278_styler,
#         });
#
#         function geo_json_7681bcf9d076fe4ec4814aa15770c278_add (data) {
#             geo_json_7681bcf9d076fe4ec4814aa15770c278
#                 .addData(data)
#                 .addTo(map_cc3f96d0ef0a064982d85a9dcb0f3f81);
#         }
#             geo_json_7681bcf9d076fe4ec4814aa15770c278_add({&quot;bbox&quot;: [-87.61262427240324, 41.81681377057218, -87.59215283879394, 41.83136624686849], &quot;features&quot;: [{&quot;bbox&quot;: [-87.61262427240324, 41.81681377057218, -87.59215283879394, 41.83136624686849], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.59215283879394, 41.81692934626684], [-87.6067081256125, 41.81681377057218], [-87.60687305833154, 41.82396480017465], [-87.61262427240324, 41.82389080436826], [-87.61063335779062, 41.83118622461551], [-87.60271020373473, 41.83136624686849], [-87.59775488402967, 41.82634380429046], [-87.59727092138688, 41.822617829443594], [-87.59215283879394, 41.81692934626684]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_24d35b80604fc9b55aee4e0551367b83_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;orange&quot;};
#             }
#         }
#
#         function geo_json_24d35b80604fc9b55aee4e0551367b83_onEachFeature(feature, layer) {
#             l

# %%
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2506294 entries, 0 to 2506293
# Data columns (total 12 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Trip ID                     object
#  1   Pickup Centroid Latitude    object
#  2   Pickup Centroid Longitude   object
#  3   Pickup Centroid Location    object
#  4   Dropoff Centroid Latitude   object
#  5   Dropoff Centroid Longitude  object
#  6   Dropoff Centroid  Location  object
#  7   Trip Start Timestamp        object
#  8   Trip End Timestamp          object
#  9   Taxi ID                     object
#  10  Fare                        object
#  11  geometry                    geometry
# dtypes: geometry(1), object(11)
# memory usage: 229.5+ MB

# %% [markdown]
# ## 1. Most popular areas

# %% [markdown]
# 1. Conduct clustering analysis of pick point and drop off locations based on their coordinates. Clusters might be different for each of the categories (pickpoints and drop-offs).

# %% [markdown]
# #### Pickpoints

# %% [markdown]
# #### Drop-offs

# %% [markdown]
# 2. Draw the borders and centroids of the clusters on a map. You will have two maps.

# %% [markdown]
# 3. Use a color scale to show which clusters (i.e. areas) have the largest number of pick
# points and drop-offs.

# %% [markdown]
# ## 2. Most popular routes

# %% [markdown]
# ## 3. City infrastructure

# %% [markdown]
# ## 4. One day of a taxi driver

# %% [markdown]
# ## 5. One day of the city

# %% [markdown]
# ## Bonus
